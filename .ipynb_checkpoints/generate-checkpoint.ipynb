# %%
import torch
from model import Transformer
import layers
from _tokenizer import VOCABULARY
from miditoolkit.midi import parser as mid_parser  
from miditoolkit.midi import containers as ct
import numpy as np

# %%
def load_model(filepath):
    
    file = torch.load(filepath)
    model = Transformer(**file["hyper_params"]).to("cuda:0" if torch.cuda.is_available() else "cpu") 
    model.load_state_dict(file["model_state_dict"])
    model.eval()
    return model.to("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def generate(model_, x, save_path, word_len = 0, mode=None, k=None, ):
    """
        Mode: 'argmax', 'categorical', 'k-top'
    
    """
    x = [1]
    if x[0] != 1:
        x = [1] + x
    
    x = torch.tensor(x, dtype=torch.int64, device="cuda:0" if torch.cuda.is_available() else "cpu")
    x = x.unsqueeze(0)
    n_dim = x.dim() + 2

    with torch.no_grad():
        if word_len:
            while word_len >= 0:
                pred = model_(x, mask=layers.create_mask(x, n_dim))
                if mode == "k-top":
                    k_top_pred = torch.topk(pred[..., -1, :], k, dim=-1)
                    pred_idx = torch.distributions.Categorical(logits=k_top_pred.values[..., -1, :]).sample()
                    pred = k_top_pred.indices[..., pred_idx]
                elif mode == "argmax":
                    pred = torch.argmax(pred[..., -1:, :], dim=-1)
                elif mode == "categorical":
                    pred = torch.distributions.Categorical(logits=pred[..., -1, :]).sample()

                # pred = torch.argmax(pred[..., -1, :], dim=-1)
                # print(pred)
                # if pred[0] == 2:
                    # return x.squeeze()[1:]
                
                x = torch.cat([x, pred.view(1, 1)], dim=-1)
                word_len -= 1
        else:
            while True:
                pred = model_(x, mask=layers.create_mask(x, n_dim))
                if mode == "k-top":
                    k_top_pred = torch.topk(pred[..., -1, :], k, dim=-1)
                    pred_idx = torch.distributions.Categorical(logits=k_top_pred.values[..., -1, :]).sample()
                    pred = k_top_pred.indices[..., pred_idx]
                elif mode == "argmax":
                    pred = torch.argmax(pred[..., -1:, :], dim=-1)
                elif mode == "categorical":
                    pred = torch.distributions.Categorical(logits=pred[..., -1, :]).sample()

                if int(pred[0]) == 2:
                    return x.squeeze()[1:]
                
                x = torch.cat([x, pred.view(1, 1)], dim=-1)

    return x.squeeze()[1:]

# %%
def _generate(model_, x, mode=None, k=None, ):
    """
        Mode: 'argmax', 'categorical', 'k-top'
    
    """
    x = [1]
    if x[0] != 1:
        x = [1] + x
    
    x = torch.tensor(x, dtype=torch.int64, device="cuda:0" if torch.cuda.is_available() else "cpu")
    x = x.unsqueeze(0)
    n_dim = x.dim() + 2
    max_length = 1000
    with torch.no_grad():
        while True:
            if max_length == 0:
                return x.squeeze()[1:]
                
            pred = model_(x, mask=layers.create_mask(x, n_dim))
            if mode == "k-top":
                k_top_pred = torch.topk(pred[..., -1, :], k, dim=-1)
                pred_idx = torch.distributions.Categorical(logits=k_top_pred.values[..., -1, :]).sample()
                pred = k_top_pred.indices[..., pred_idx]
            elif mode == "argmax":
                pred = torch.argmax(pred[..., -1:, :], dim=-1)
            elif mode == "categorical":
                pred = torch.distributions.Categorical(logits=pred[..., -1, :]).sample()

            if int(pred[0]) == 2:
                return x.squeeze()[1:]
#             print(pred)
            max_length -= 1
            x = torch.cat([x, pred.view(1, 1)], dim=-1)
    return x.squeeze()[1:]

# %%
def num2bin(num: int):
    cur = 0
    seq = []
    while num >= 1/(1<<cur):
        seq.append(1<<cur)

# %%
def process_timeframe(time_frame: torch.Tensor) -> list:
    time_list = []
    current_time = 0.0
    for symbol in time_frame:
        value = 1/int(symbol.split("_")[-1])
        if current_time + value > 1:
            diff = 1.0 - current_time

# %%
# model = load_model("./checkpoints/modelFPT16.pt")
model_note = load_model("./checkpoints/fpt_model_note_frames.pt")
model_time = load_model("./checkpoints/fpt_model_time_frames.pt")

# %%
tokens_note = torch.Tensor([1]).to("cuda:0")
tokens_time = torch.Tensor([1]).to("cuda:0")

# %%
seg_note = _generate(model_=model_note, x=tokens_note, mode="k-top", k=10)
seg_time = _generate(model_=model_time, x=tokens_time, mode="k-top", k=10)

# %%
# for i in seg_note:
#     print(VOCABULARY["NOTES"][i])

# %%
for i in seg_time:
    print(VOCABULARY["SYMBOL"][i])
# Out:
# Note_2
# Symbol_4
# Note_4
# Note_2
# Symbol_4
# Note_4
# Note_4
# Note_4
# Note_2
# Note_4
# Note_4
# Symbol_2
# Symbol_4
# Note_4
# Note_4
# Symbol_4
# Note_4
# Note_4
# Note_4
# Note_8
# Note_4
# Note_4
# Note_4
# Note_4
# Note_4
# Symbol_8
# Note_4
# Note_4
# Note_4
# Note_4
# Note_4
# Note_4
# Note_4
# Note_4
# Note_4
# Note_4
# Symbol_8
# Note_2
# Symbol_2

# %%
seg_len = 20
tokens = torch.Tensor([1]).to("cuda:0")
while seg_len > 0:
    seg_token = _generate(model_=model, x=tokens[-1:], mode="k-top", k=10)
    tokens = torch.cat((tokens, seg_token), dim=0)
    seg_len -= 1
tokens = tokens.int()[1:]

# %%
for i in tokens:
    print(VOCABULARY[int(i)])
# Out:
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_4
# Note_off_65
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_4
# Note_off_67
# Symbol_4
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Note_on_76
# Duration_1
# Note_off_76
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Duration_2
# Note_off_81
# Note_on_79
# Duration_1
# Note_off_79
# Note_on_81
# Duration_1
# Note_off_81
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_76
# Duration_1
# Note_off_76
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_76
# Duration_1
# Note_off_76
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_2
# Note_off_77
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_79
# Duration_1
# Note_off_79
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_81
# Duration_1
# Note_off_81
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_77
# Duration_2
# Note_off_77
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_77
# Duration_1
# Note_off_77
# Note_on_81
# Duration_1
# Note_off_81
# Duration_1
# Note_off_64
# Note_on_66
# Duration_1
# Note_off_52
# Note_on_50
# Duration_1
# Note_off_50
# Note_on_52
# Duration_1
# Note_off_52
# Duration_2
# Note_off_79
# Note_on_81
# Duration_1
# Note_off_81
# Note_on_79
# Duration_1
# Note_off_79
# Note_on_81
# Duration_1
# Note_off_81
# Note_on_79
# Duration_1
# Note_off_79
# Note_on_79
# Duration_4
# Note_off_79
# Note_on_79
# Duration_1
# Note_off_79
# Note_on_81
# Duration_1
# Note_off_81
# Note_on_74
# Duration_4
# Note_off_74
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_79
# Duration_1
# Note_off_79
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_72
# Duration_4
# Note_off_72
# Symbol_2
# Symbol_4
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_4
# Note_off_65
# Note_on_62
# Duration_4
# Note_off_62
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_60
# Duration_4
# Note_off_60
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_4
# Note_off_62
# Symbol_2
# Symbol_4
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_71
# Duration_2
# Note_off_71
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_69
# Duration_4
# Note_off_69
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Symbol_2
# Note_on_74
# Duration_1
# Note_off_74
# Symbol_4
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_67
# Duration_1
# Note_off_67
# Duration_1
# Note_off_50
# Note_on_52
# Duration_1
# Note_off_52
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_4
# Note_off_62
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_57
# Duration_1
# Note_off_57
# Note_on_60
# Duration_2
# Note_off_60
# Note_on_64
# Duration_2
# Note_off_64
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_4
# Note_off_62
# Symbol_2
# Note_on_62
# Duration_4
# Note_off_62
# Symbol_2
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_60
# Duration_2
# Note_off_60
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_55
# Duration_2
# Note_off_55
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_4
# Note_off_60
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_62
# Duration_4
# Note_off_62
# Symbol_2
# Note_off_65
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_74
# Duration_1
# Note_off_74
# Symbol_4
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_69
# Duration_4
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_60
# Duration_2
# Note_off_60
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_2
# Note_off_67
# Symbol_4
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_72
# Duration_2
# Note_off_72
# Note_on_69
# Duration_2
# Note_off_69
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_2
# Symbol_4
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_74
# Duration_1
# Duration_4
# Note_off_64
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_55
# Duration_4
# Note_off_55
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_76
# Duration_1
# Note_off_76
# Note_on_73
# Duration_1
# Note_off_73
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_1
# Note_off_62
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_50
# Note_on_52
# Duration_1
# Note_off_52
# Note_on_50
# Duration_1
# Note_off_50
# Note_on_52
# Duration_1
# Note_off_52
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_4
# Note_off_67
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_2
# Note_off_60
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_55
# Duration_1
# Note_off_55
# Note_on_57
# Duration_1
# Note_off_57
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Symbol_4
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_60
# Duration_1
# Duration_4
# Note_off_50
# Symbol_2
# Symbol_4
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_67
# Duration_4
# Note_off_67
# Symbol_4
# Note_on_69
# Duration_4
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_65
# Duration_2
# Note_off_65
# Symbol_2
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_2
# Symbol_4
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_4
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_77
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_4
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_2
# Note_off_65
# Symbol_2
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_74
# Duration_4
# Note_off_74
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_77
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_4
# Note_off_62
# Symbol_2
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Note_on_55
# Duration_1
# Note_off_55
# Symbol_2
# Symbol_4
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_71
# Duration_4
# Note_off_71
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Symbol_4
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Symbol_4
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_76
# Duration_1
# Note_off_76
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_72
# Duration_1
# Note_off_72
# Symbol_4
# Note_on_65
# Duration_2
# Note_off_65
# Symbol_2
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_2
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_2
# Note_off_69
# Duration_2
# Note_off_66
# Duration_2
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Symbol_4
# Note_on_72
# Duration_4
# Note_off_72
# Symbol_2
# Symbol_4
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_72
# Duration_4
# Note_off_72
# Symbol_2
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_2
# Note_off_65
# Symbol_2
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_72
# Duration_2
# Note_off_72
# Note_on_74
# Duration_1
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_2
# Note_off_67
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_71
# Duration_2
# Note_off_71
# Note_on_69
# Duration_2
# Note_off_69
# Note_on_72
# Duration_2
# Note_off_72
# Note_on_69
# Duration_2
# Note_off_69
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_72
# Duration_1
# Note_off_72
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Symbol_4
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_69
# Duration_1
# Note_off_65
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_64
# Duration_4
# Note_off_64
# Note_on_67
# Duration_2
# Note_off_67
# Note_on_65
# Duration_1
# Note_off_65
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_4
# Note_off_69
# Symbol_2
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_72
# Duration_2
# Note_off_72
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_71
# Duration_1
# Note_off_71
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_60
# Duration_1
# Note_off_60
# Symbol_4
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Symbol_4
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_4
# Note_off_65
# Symbol_2
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_65
# Duration_1
# Note_off_65
# Symbol_2
# Note_on_72
# Duration_2
# Duration_1
# Note_off_73
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_81
# Duration_1
# Note_off_81
# Note_on_81
# Duration_1
# Note_off_81
# Note_on_81
# Duration_4
# Note_off_50
# Symbol_2
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Note_on_74
# Duration_1
# Note_off_74
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_2
# Note_off_77
# Note_on_77
# Duration_4
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Symbol_4
# Note_on_77
# Duration_1
# Note_off_77
# Symbol_2
# Note_on_77
# Duration_2
# Note_off_77
# Symbol_2
# Duration_4
# Note_off_55
# Note_on_55
# Duration_1
# Note_off_55
# Note_on_57
# Duration_1
# Note_off_57
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_57
# Duration_1
# Note_off_57
# Note_on_55
# Duration_1
# Note_off_55
# Note_on_57
# Duration_1
# Note_off_57
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_60
# Duration_2
# Note_off_60
# Note_on_57
# Duration_1
# Note_off_57
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_60
# Duration_1
# Note_off_60
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_69
# Duration_1
# Note_off_69
# Note_on_62
# Duration_2
# Note_off_62
# Note_on_67
# Duration_1
# Note_off_67
# Symbol_4
# Note_on_69
# Duration_4
# Note_off_69
# Note_on_67
# Duration_4
# Note_off_67
# Note_on_62
# Duration_1
# Note_off_62
# Note_on_64
# Duration_1
# Note_off_64
# Note_on_67
# Duration_1
# Note_off_67
# Note_on_69
# Duration_1
# Note_off_69
# Symbol_4
# Note_on_69
# Duration_4
# Note_off_69

# %%
def convert_to_midi(midi_data, save_path, ticks_per_beat = 120, tempo=120, time_signature_change = {"numerator": 4, "denominator": 4}):
    mido_obj = mid_parser.MidiFile()
    mido_obj.ticks_per_beat = ticks_per_beat
    mido_obj.time_signature_changes.append(ct.TimeSignature(**time_signature_change, time=0))
    mido_obj.tempo_changes.append(ct.TempoChange(tempo=tempo, time=0))
    
    track = ct.Instrument(program=0, is_drum=False, name="piano")
    mido_obj.instruments = [track]

    current_time = 0
    current_note = {
        "start": 0,
        "end": 0,
        "pitch": 0,
        "velocity": 90
    }
    
    for idx in range(len(midi_data)):
        _id = int(midi_data[idx])
        
        if "Note_on" in VOCABULARY[_id]:
            midi_data = midi_data[idx:]
            break
    
    for i in midi_data:
        i = VOCABULARY[i] 
        
        if "Symbol" in i:
            value = int(i.split("_")[-1])
            current_time += 2*ticks_per_beat//value
        if "Note_on" in i:
            current_note["start"] = current_time
        if "Duration" in i:
            value = int(i.split("_")[-1])
            current_time += 2*ticks_per_beat//value
        if "Note_off" in i:
            value = int(i.split("_")[-1])
            current_note["pitch"] = value
            current_note["end"] = current_time
            
            note = ct.Note(**current_note)
            mido_obj.instruments[0].notes.append(note)
                        
    print(mido_obj)
    mido_obj.dump(save_path)

# %%
convert_to_midi(tokens, "./midi_gen/b1_2_4.mid", ticks_per_beat = 400, tempo=400, time_signature_change={"numerator":2, "denominator": 4} )
# Out:
# ticks per beat: 400
# max tick: 0
# tempo changes: 1
# time sig: 1
# key sig: 0
# markers: 0
# lyrics: False
# instruments: 1

# %%
from miditoolkit.midi import parser as mid_parser  
from miditoolkit.midi import containers as ct
import numpy as np

# %%
# def convert_to_midi(midi_data, save_path, name):
#     mido_obj = mid_parser.MidiFile()
#     beat_resol = mido_obj.ticks_per_beat
#     track = ct.Instrument(program=0, is_drum=False, name=name)
#     mido_obj.instruments = [track]

#     current_time = 0
#     current_note = {
#         "start": 0,
#         "end": 0,
#         "pitch": 0,
#         "velocity": 0
#     }
#     for i in midi_data:
#         i = VOCABULARY[i]
#         if "Rest_" in i:
#             value = int(i.split("_")[-1])
#             current_time += value*8
#         elif "Note_on" in i:
#             value = int(i.split("_")[-1])
#             current_note["pitch"] = value
#             current_note["start"] = current_time
#         elif "Duration_" in i:
#             value = int(i.split("_")[-1])*8
#             current_time += value*8
#         elif "Velocity_" in i:
#             value = int(i.split("_")[-1])*8
#             current_note["velocity"] = value
#         elif "Note_off" in i:
#             value = int(i.split("_")[-1])
#             current_note["pitch"] = value 
#             current_note["end"] = current_time 

#             note = ct.Note(**current_note)
#             mido_obj.instruments[0].notes.append(note)
                        
#     mido_obj.dump(save_path)

# %%
def convert_to_midi1(midi_data, save_path, ticks_per_beat = 120, time_signature_change = {"numerator": 4, "denominator": 4}):
    mido_obj = mid_parser.MidiFile()
    mido_obj.ticks_per_beat = ticks_per_beat
    mido_obj.time_signature_changes.append(ct.TimeSignature(**time_signature_change, time=0))
    
    track = ct.Instrument(program=0, is_drum=False, name="piano")
    mido_obj.instruments = [track]

    current_time = 0
    current_note = {
        "start": 0,
        "end": 0,
        "pitch": 0,
        "velocity": 90
    }
    for i in midi_data:
        i = VOCABULARY[i] 
        # Note_off_pitch
        if "Note_off" in i:
            value = int(i.split("_")[-1])
            current_note["pitch"] = value 
            current_note["start"] = current_time 
            current_time += ticks_per_beat
            current_note["end"] = current_time
            
            note = ct.Note(**current_note)
            mido_obj.instruments[0].notes.append(note)
                        
    print(mido_obj)
    mido_obj.dump(save_path)

# %%
convert_to_midi1(tokens, "./midi_gen/b1_2_4.mid", ticks_per_beat = 100, time_signature_change={"numerator":2, "denominator": 4} )
# Out:
# ticks per beat: 100
# max tick: 0
# tempo changes: 0
# time sig: 1
# key sig: 0
# markers: 0
# lyrics: False
# instruments: 1

# %%
import tokenizer
from miditoolkit.midi import parser as mid_parser  
from miditoolkit.midi import containers as ct
import miditoolkit

# %%
midi = miditoolkit.midi.parser.MidiFile("./datasets/mid/Bac_Bo/Lý_Cây_Đa.mid")
midi_ = miditoolkit.midi.parser.MidiFile("./midi_gen/b8.mid")

# %%
midi_.time_signature_changes[0]
# Out:
# TimeSignature(numerator=4, denominator=4, time=0)

# %%
midi.instruments[0].notes
# Out:
# [Note(start=480, end=935, pitch=72, velocity=80),
#  Note(start=960, end=1415, pitch=74, velocity=80),
#  Note(start=1440, end=1667, pitch=74, velocity=80),
#  Note(start=1680, end=1799, pitch=72, velocity=80),
#  Note(start=1800, end=1913, pitch=74, velocity=80),
#  Note(start=1920, end=2375, pitch=76, velocity=80),
#  Note(start=2400, end=2627, pitch=74, velocity=80),
#  Note(start=2640, end=2759, pitch=72, velocity=80),
#  Note(start=2760, end=2873, pitch=74, velocity=80),
#  Note(start=2880, end=3107, pitch=76, velocity=80),
#  Note(start=3120, end=3239, pitch=76, velocity=80),
#  Note(start=3240, end=3353, pitch=72, velocity=80),
#  Note(start=3360, end=3599, pitch=72, velocity=80),
#  Note(start=3600, end=3827, pitch=74, velocity=80),
#  Note(start=3840, end=4067, pitch=72, velocity=80),
#  Note(start=4080, end=4307, pitch=72, velocity=80),
#  Note(start=4320, end=4547, pitch=74, velocity=80),
#  Note(start=4560, end=4679, pitch=72, velocity=80),
#  Note(start=4680, end=4793, pitch=74, velocity=80),
#  Note(start=4800, end=5027, pitch=76, velocity=80),
#  Note(start=5040, end=5159, pitch=76, velocity=80),
#  Note(start=5160, end=5273, pitch=74, velocity=80),
#  Note(start=5280, end=5519, pitch=72, velocity=80),
#  Note(start=5520, end=5747, pitch=74, velocity=80),
#  Note(start=5760, end=5987, pitch=72, velocity=80),
#  Note(start=6000, end=6227, pitch=72, velocity=80),
#  Note(start=6240, end=6467, pitch=74, velocity=80),
#  Note(start=6480, end=6599, pitch=72, velocity=80),
#  Note(start=6600, end=6713, pitch=74, velocity=80),
#  Note(start=6720, end=6839, pitch=76, velocity=80),
#  Note(start=6840, end=6953, pitch=79, velocity=80),
#  Note(start=6960, end=7079, pitch=76, velocity=80),
#  Note(start=7080, end=7193, pitch=74, velocity=80),
#  Note(start=7200, end=7439, pitch=72, velocity=80),
#  Note(start=7440, end=7667, pitch=74, velocity=80),
#  Note(start=7680, end=8639, pitch=72, velocity=80),
#  Note(start=8640, end=9095, pitch=72, velocity=80),
#  Note(start=9120, end=9359, pitch=72, velocity=80),
#  Note(start=9360, end=9587, pitch=76, velocity=80),
#  Note(start=9600, end=9827, pitch=74, velocity=80),
#  Note(start=9840, end=10067, pitch=74, velocity=80),
#  Note(start=10080, end=10319, pitch=72, velocity=80),
#  Note(start=10320, end=10547, pitch=76, velocity=80),
#  Note(start=10560, end=10799, pitch=74, velocity=80),
#  Note(start=10800, end=11027, pitch=72, velocity=80),
#  Note(start=11040, end=11267, pitch=67, velocity=80),
#  Note(start=11280, end=11519, pitch=67, velocity=80),
#  Note(start=11520, end=11747, pitch=67, velocity=80),
#  Note(start=11760, end=11987, pitch=72, velocity=80),
#  Note(start=12000, end=12239, pitch=72, velocity=80),
#  Note(start=12240, end=12467, pitch=67, velocity=80),
#  Note(start=12480, end=13163, pitch=67, velocity=80),
#  Note(start=13200, end=13427, pitch=72, velocity=80),
#  Note(start=13440, end=13799, pitch=67, velocity=80),
#  Note(start=13800, end=13913, pitch=72, velocity=80),
#  Note(start=13920, end=14159, pitch=69, velocity=80),
#  Note(start=14160, end=14387, pitch=67, velocity=80),
#  Note(start=14400, end=14627, pitch=65, velocity=80),
#  Note(start=14640, end=14867, pitch=65, velocity=80),
#  Note(start=14880, end=15107, pitch=69, velocity=80),
#  Note(start=15120, end=15239, pitch=67, velocity=80),
#  Note(start=15240, end=15353, pitch=69, velocity=80),
#  Note(start=15360, end=15587, pitch=72, velocity=80),
#  Note(start=15600, end=15719, pitch=72, velocity=80),
#  Note(start=15720, end=15833, pitch=71, velocity=80),
#  Note(start=15840, end=16079, pitch=67, velocity=80),
#  Note(start=16080, end=16307, pitch=69, velocity=80),
#  Note(start=16320, end=16547, pitch=67, velocity=80),
#  Note(start=16560, end=16787, pitch=67, velocity=80),
#  Note(start=16800, end=17027, pitch=69, velocity=80),
#  Note(start=17040, end=17159, pitch=67, velocity=80),
#  Note(start=17160, end=17273, pitch=69, velocity=80),
#  Note(start=17280, end=17399, pitch=72, velocity=80),
#  Note(start=17400, end=17513, pitch=76, velocity=80),
#  Note(start=17520, end=17639, pitch=74, velocity=80),
#  Note(start=17640, end=17753, pitch=72, velocity=80),
#  Note(start=17760, end=17999, pitch=67, velocity=80),
#  Note(start=18000, end=18227, pitch=69, velocity=80),
#  Note(start=18240, end=19199, pitch=67, velocity=80),
#  Note(start=19200, end=19655, pitch=67, velocity=80),
#  Note(start=19680, end=20135, pitch=72, velocity=80),
#  Note(start=20160, end=20615, pitch=74, velocity=80),
#  Note(start=20640, end=20867, pitch=74, velocity=80),
#  Note(start=20880, end=20999, pitch=72, velocity=80),
#  Note(start=21000, end=21113, pitch=74, velocity=80),
#  Note(start=21120, end=21575, pitch=76, velocity=80),
#  Note(start=21600, end=21827, pitch=74, velocity=80),
#  Note(start=21840, end=21959, pitch=72, velocity=80),
#  Note(start=21960, end=22073, pitch=74, velocity=80),
#  Note(start=22080, end=22307, pitch=76, velocity=80),
#  Note(start=22320, end=22439, pitch=76, velocity=80),
#  Note(start=22440, end=22553, pitch=74, velocity=80),
#  Note(start=22560, end=22799, pitch=72, velocity=80),
#  Note(start=22800, end=23027, pitch=74, velocity=80),
#  Note(start=23040, end=23267, pitch=72, velocity=80),
#  Note(start=23280, end=23507, pitch=72, velocity=80),
#  Note(start=23520, end=23747, pitch=74, velocity=80),
#  Note(start=23760, end=23879, pitch=72, velocity=80),
#  Note(start=23880, end=23993, pitch=74, velocity=80),
#  Note(start=24000, end=24227, pitch=76, velocity=80),
#  Note(start=24240, end=24359, pitch=76, velocity=80),
#  Note(start=24360, end=24473, pitch=74, velocity=80),
#  Note(start=24480, end=24719, pitch=72, velocity=80),
#  Note(start=24720, end=24947, pitch=74, velocity=80),
#  Note(start=24960, end=25187, pitch=72, velocity=80),
#  Note(start=25200, end=25427, pitch=72, velocity=80),
#  Note(start=25440, end=25667, pitch=74, velocity=80),
#  Note(start=25680, end=25799, pitch=72, velocity=80),
#  Note(start=25800, end=25913, pitch=74, velocity=80),
#  Note(start=25920, end=26039, pitch=76, velocity=80),
#  Note(start=26040, end=26153, pitch=79, velocity=80),
#  Note(start=26160, end=26279, pitch=76, velocity=80),
#  Note(start=26280, end=26393, pitch=74, velocity=80),
#  Note(start=26400, end=26639, pitch=72, velocity=80),
#  Note(start=26640, end=26867, pitch=74, velocity=80),
#  Note(start=26880, end=27839, pitch=72, velocity=80),
#  Note(start=27840, end=28295, pitch=72, velocity=80),
#  Note(start=28320, end=28559, pitch=72, velocity=80),
#  Note(start=28560, end=28787, pitch=76, velocity=80),
#  Note(start=28800, end=29027, pitch=74, velocity=80),
#  Note(start=29040, end=29267, pitch=74, velocity=80),
#  Note(start=29280, end=29519, pitch=72, velocity=80),
#  Note(start=29520, end=29747, pitch=76, velocity=80),
#  Note(start=29760, end=29999, pitch=74, velocity=80),
#  Note(start=30000, end=30227, pitch=72, velocity=80),
#  Note(start=30240, end=30467, pitch=67, velocity=80),
#  Note(start=30480, end=30719, pitch=67, velocity=80),
#  Note(start=30720, end=30947, pitch=67, velocity=80),
#  Note(start=30960, end=31187, pitch=72, velocity=80),
#  Note(start=31200, end=31439, pitch=72, velocity=80),
#  Note(start=31440, end=31667, pitch=67, velocity=80),
#  Note(start=31680, end=32363, pitch=67, velocity=80),
#  Note(start=32400, end=32627, pitch=72, velocity=80),
#  Note(start=32640, end=32999, pitch=67, velocity=80),
#  Note(start=33000, end=33113, pitch=72, velocity=80),
#  Note(start=33120, end=33359, pitch=69, velocity=80),
#  Note(start=33360, end=33587, pitch=67, velocity=80),
#  Note(start=33600, end=33827, pitch=65, velocity=80),
#  Note(start=33840, end=34067, pitch=65, velocity=80),
#  Note(start=34080, end=34307, pitch=69, velocity=80),
#  Note(start=34320, end=34439, pitch=67, velocity=80),
#  Note(start=34440, end=34553, pitch=69, velocity=80),
#  Note(start=34560, end=34787, pitch=72, velocity=80),
#  Note(start=34800, end=34919, pitch=72, velocity=80),
#  Note(start=34920, end=35033, pitch=69, velocity=80),
#  Note(start=35040, end=35279, pitch=67, velocity=80),
#  Note(start=35280, end=35507, pitch=69, velocity=80),
#  Note(start=35520, end=35747, pitch=67, velocity=80),
#  Note(start=35760, end=35987, pitch=67, velocity=80),
#  Note(start=36000, end=36227, pitch=69, velocity=80),
#  Note(start=36240, end=36359, pitch=67, velocity=80),
#  Note(start=36360, end=36473, pitch=69, velocity=80),
#  Note(start=36480, end=36599, pitch=72, velocity=80),
#  Note(start=36600, end=36713, pitch=76, velocity=80),
#  Note(start=36720, end=36839, pitch=74, velocity=80),
#  Note(start=36840, end=36953, pitch=72, velocity=80),
#  Note(start=36960, end=37199, pitch=67, velocity=80),
#  Note(start=37200, end=37427, pitch=69, velocity=80),
#  Note(start=37440, end=38399, pitch=67, velocity=80),
#  Note(start=38400, end=38855, pitch=67, velocity=80)]

# %%
from music21 import converter, instrument, note, chord
import glob

# %%
def read_midi(path):
    notes = []
    midi = converter.parse(path)
    s2 = instrument.partitionByInstrument(midi)
    notes_to_parse = s2.parts[0].recurse() 
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        # elif isinstance(element, chord.Chord):
        
        #     notes.append('.'.join(str(n) for n in element.normalOrder))
    return notes

# %%
data_path = "./datasets/mid/Bac_Bo/Lý_Cây_Đa.mid"
notes = []

# %%
midi = read_midi(data_path)

# %%
len(midi)
# Out:
# 160
